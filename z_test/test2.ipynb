# %%
import requests
from pprint import pprint

# %%
url = 'http://localhost:5006/webhooks/callassist/webhook'
data = {
  "sender": "txs3s74y4y44658x",  
  "message": "servicer：邮政管理局"
  # "message": "servicer:语言模型，嗯，好的，那您来电号码到时候留意接听了，也让他尽快给您回复，您看还有其他可以帮您的吗？"
  # "message": "5:00~7:00的取件时间。"
  # "message": "嗯，就是发不了发过来的了，一个月567"
  # "message": '我要投诉的'
  # "message": "白酒,发件方：是 王先生1234567890123456780"
  # "message": "手机号1850235"
  # "message": "我现在没有，我就想问一下，10吨我当时已经跟商家协商过退款了，为啥你们快递员今天已经过了四五六天再给我打电话说是我的问题。"
  # "message": "你好"
  # "message": "你帮我你帮我看一下这个件2月27号到的，然后现在我那个客户说没有收到货。"
  # "message": "五六七八九零一二三四"
  # "message": "53698 yt 1850850729053"
  # ,"metadata" :{'express_id':"YT1234567890127"}
}
# pprint(data["message"])
# d = {"message": '网点\分部客服态度问题'}
# print(d["message"])
res = requests.post(url, json=data)
# pprint(res.text)yt1850850729053
d = res.json()
pprint(d)
# Out:
# [{'recipient_id': 'txs3s74y4y44658x', 'text': '标准话术执行率：90%'},
#  {'recipient_id': 'txs3s74y4y44658x', 'text': '违规话术识别：无违规话术'},
#  {'api_exception': 0,
#   'last_message': {'confidence': 0.6029,
#                    'exact_hit': False,
#                    'input_channel': 'callassist',
#                    'intent_name': 'input_servicer',
#                    'slots': {},
#                    'text': '语言模型，邮政管理局',
#                    'top2_diff': 0.269},
#   'recipient_id': 'txs3s74y4y44658x',
#   'story': 'faq'}]

# %%
from rasa_sdk.events import (
    ActionExecuted,
    SlotSet,
    SessionStarted,
)

evt = SlotSet(key = "name", value = "Mary")
evt = ActionExecuted('action_listen')

evt
# Out:
# {'event': 'action',
#  'name': 'action_listen',
#  'policy': None,
#  'confidence': None,
#  'timestamp': None}

# %%
# url = 'http://10.130.118.125:5005/webhooks/wdgj/webhook'
url = 'http://10.130.118.125:5006/webhooks/callassist/webhook'
data = {
  "sender": "tstx1c4gddd4056465",  
  # "message": "servicer：有了解的，我们边会尽快处理给您进行回复的，请问还有其他问题吗"
  "message": "servicer: 邮政管理局"
  # "message": "嗯，就是发不了发过来的了，一一一两点多。"
  # "message": "呃这个单号8960357027501查一下"
  # "message": "呃如果是一个件退回，可能是有问题，如果两个件都退回了的话，我们需要帮您去核实到底是哪里出了问题，尽快给您处理，给您回电啊。"
  # "message": "就是拨电线本以及各方面嘛，跟你说了多功能干事情，你只要单号对了就可以了。"
  # "message": "李吧，先生"
  # "message": "呃这个白酒,发件方：是 王先生1234567890123456780"
  # ,"metadata" :{'express_id': 'YT7457800025849', 'phone': '18789803041'}
}
res = requests.post(url, json=data)
pprint(res)
# pprint(res.text)
d = res.json()
pprint(d)
# Out:
# <Response [200]>
# [{'recipient_id': 'tstx1c4gddd4056465', 'text': '标准话术执行率：90%'},
#  {'recipient_id': 'tstx1c4gddd4056465', 'text': '违规话术识别：无违规话术'},
#  {'api_exception': 0,
#   'last_message': {'confidence': 0.6029,
#                    'exact_hit': False,
#                    'input_channel': 'callassist',
#                    'intent_name': 'input_servicer',
#                    'slots': {},
#                    'text': '语言模型， 邮政管理局',
#                    'top2_diff': 0.269},
#   'recipient_id': 'tstx1c4gddd4056465',
#   'story': 'faq'}]

# %%
import re
repat_numbers = re.compile(r"[零令林一幺妖二两三四五六七八九]{3,}")

# %%
mt = repat_numbers.search("二三九")
print(mt.group())
# Out:
# 二三九

# %%
import re
repat_numbers = re.compile("[1幺妖][3-9三四五六七八九][\d 零令林一幺妖二两三四五六七八九]{,9}")
mt = repat_numbers.search("183 九45 6")
print(mt)
# Out:
# <re.Match object; span=(0, 9), match='183 九45 6'>

# %%
print(re.search('q\s+w', 'dddq  wer'))
express_id_pat4 = re.compile("(?<!\\d)\\d{13}(?!\\d)")
express_id_pat4.search('1234567890123')
# Out:
# <re.Match object; span=(3, 7), match='q  w'>
# <re.Match object; span=(0, 13), match='1234567890123'>

# %% [markdown]
# ''

# %% [markdown]
# n	普通名词	f	方位名词	s	处所名词	t	时间
# nr	人名	ns	地名	nt	机构名	nw	作品名
# nz	其他专名	v	普通动词	vd	动副词	vn	名动词
# a	形容词	ad	副形词	an	名形词	d	副词
# m	数量词	q	量词	r	代词	p	介词
# c	连词	u	助词	xc	其他虚词	w	标点符号
# PER	人名	LOC	地名	ORG	机构名	TIME	时间

# %%
import jieba
import jieba.posseg as pseg

# %%
f = pseg.lcut('诸葛')
print(type(f), f)
f = jieba.lcut('yt664322344221323退了吗')
# for i in pseg.cut('我是公孙策'):
print(type(f), f)
# Out:
# <class 'list'> [pair('诸葛', 'nr')]
# <class 'list'> ['yt664322344221323', '退', '了', '吗']

# %%
for i in range(4, 1, -1):
    print(i)
ls = [1,2,3,4]
ls[-3:]
jj = '网点\分部客服态度问题'
print(jj)
# Out:
# 4
# 3
# 2
# 网点\分部客服态度问题

# %%
xing = '王张李刘陈杨黄周胡赵吴徐孙朱宋郭罗林曹马高何梁郑韩谢唐董夏傅冯许袁薛姚于彭肖曾谭卢苏贾余毛汪邓戴江丁蔡叶程闫钟廖田任姜范方潘杜魏沈熊金陆郝孔白崔吕邱秦蒋石史顾侯邵孟邹段钱汤黎常尹武乔贺赖龚庞樊殷施翟倪严牛陶俞章鲁葛韦毕聂焦向柳邢骆岳齐梅庄涂祁耿詹关费纪靳童欧甄裴屈鲍覃霍司柯阮房'


len(xing)
# Out:
# 146

# %%
text_ls = [
'行，那我这边的话呢，帮您去催促一下网点给您回复。',
'啊其他还有问题吗？',
'您还有其他需要咨询的吗？',
'好那我们这边催促加急给您回复啊。',
'那您还有其他需要咨询的吗？',
'唉，好请问还有别的问题吗？',
'请问还有其他需要咨询的吗？',
'还有其他可以帮到您吗？',
'好的，这边马上帮您联系处理，请问还有其他需要咨询的吗？',
'你看还有别的可以帮您的吗？',
'好的，还有啥问题吗',
'嗯，明白我这边的话是给您上报了，请问还有其他问题吗？',
'好的，这边还有其他需要咨询的吗？',
'好的，还有其他可以帮到您吗？',
'嗯，好，那您这边还有其他问题吗？',
'您对回电的时间有什么要求，我们下发工单，正常情况下是在24小时之内给您回电话。',
'你们我知道你们怎么判定它是稻子的。',
'还没取过吗？',
'根据物流信息来看的话，预计是在10号的时候可以到。',
'我给您去投诉，如何处理给您回电，您注意接听电话啊。',
'好的，那这边以短信的形式发送到您手机了，先生注意查收。',
'肯定是这样的女士，我们去联系一下揽收网点，联系人给您回电话，您看可以吗？您这边消消气。',
'这个的话呢，发货的话以当地网点为准啊，如果发不出去的话，我们这边也是没有办法的，我们这边只催件查件的，还没有其他问题。',
'我知道了，就是我有棉被吗？'
]

# %%
url = 'http://10.130.118.125:5006/webhooks/callassist/webhook'
for text in text_ls:
    # url = 'http://10.7.132.200:5006/webhooks/callassist/webhook'
    data = {
    "sender": "tstx1c4g056465",  
    # "message": "servicer：嗯，74541354"
    "message": f"servicer：{text}"
    # "message": "免贵姓黄，我想问一下"
    # "message": "呃这个单号8960357027501"
    # "message": "呃如果是一个件退回，可能是有问题，如果两个件都退回了的话，我们需要帮您去核实到底是哪里出了问题，尽快给您处理，给您回电啊。"
    # "message": "2345"
    # "message": "53698 yt 2515619553698"
    # "message": "呃这个白酒,发件方：是 王先生1234567890123456780"
    # ,"metadata" :{'express_id':"YT1234567890123"}
    }
    res = requests.post(url, json=data)
    # pprint(res)
    # pprint(res.text)
    d = res.json()
    print(d[-1]['last_message'])
# Out:
# {'text': '语言模型，行，那我这边的话呢，帮您去催促一下网点给您回复。', 'input_channel': 'callassist', 'intent_name': 'input_servicer', 'confidence': 0.8724, 'top2_diff': 0.7769, 'exact_hit': False, 'slots': {}}
# {'text': '语言模型，啊其他还有问题吗？', 'input_channel': 'callassist', 'intent_name': 'predict_call_end', 'confidence': 0.8414, 'top2_diff': 0.7313, 'exact_hit': False, 'slots': {}}
# {'text': '语言模型，您还有其他需要咨询的吗？', 'input_channel': 'callassist', 'intent_name': 'predict_call_end', 'confidence': 0.843, 'top2_diff': 0.75, 'exact_hit': False, 'slots': {}}
# {'text': '语言模型，好那我们这边催促加急给您回复啊。', 'input_channel': 'callassist', 'intent_name': 'input_servicer', 'confidence': 0.8787, 'top2_diff': 0.8054, 'exact_hit': False, 'slots': {}}
# {'text': '语言模型，那您还有其他需要咨询的吗？', 'input_channel': 'callassist', 'intent_name': 'predict_call_end', 'confidence': 0.8811, 'top2_diff': 0.8144, 'exact_hit': False, 'slots': {}}
# ...

# %%
user_messages=[{'intent': 'input_servicer', 'text': '模型函数，你好，也可以。', 'usr_type': 1, 'sender_id': '1712891793.101216161', 'express_id_piece': True, 'express_id': False}, {'intent': 'input_servicer', 'text': '模型函数，你好，也可以。', 'usr_type': 1}, {'intent': 'check_express_status', 'text': '请帮我查一个件。', 'usr_type': 0}, {'intent': 'check_express_status', 'text': '请帮我查一个件。', 'usr_type': 0}, {'intent': 'check_express_status', 'text': '请帮我查一个件。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，你帮我查一个签。对。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，这个单号是指。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，这个单号是指。', 'usr_type': 1}, {'intent': 'ask_express_id', 'text': '快递单号是。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，YT2819001。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，YT2819001。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，8039。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，8039。', 'usr_type': 1}, {'intent': 'inform', 'text': 'ytn81900548037。', 'usr_type': 0}, {'intent': 'inform', 'text': 'ytn81900548037。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，再报一遍。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，再报一遍。', 'usr_type': 1}, {'intent': 'angry', 'text': '我不玩。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，YT2821。', 'usr_type': 1}, {'intent': 'inform', 'text': '219。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，48037。', 'usr_type': 1}, {'intent': 'inform', 'text': '4803。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，知道吧？', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，知道吧？', 'usr_type': 1}, {'intent': 'angry', 'text': '喂。', 'usr_type': 0}, {'intent': 'angry', 'text': '喂。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，听得到吗？', 'usr_type': 1}, {'intent': 'angry', 'text': '听得到吗？', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，那个快递单号可以。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，那个快递单号可以。', 'usr_type': 1}, {'intent': 'ask_express_id', 'text': '帮我查一个件快递单号，我也。', 'usr_type': 0}, {'intent': 'inform', 'text': 'yt32819005448037。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，YPRI.', 'usr_type': 1}, {'intent': 'inform', 'text': 'ypr819005448037。', 'usr_type': 0}, {'intent': 'inform', 'text': 'ypr819005448037。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，Y.', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，Y.', 'usr_type': 1}, {'intent': 'online', 'text': 'y.', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，喂。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，喂。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，821。', 'usr_type': 1}, {'intent': 'inform', 'text': 'yt2819005448037。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，我是。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，我是。', 'usr_type': 1}, {'intent': 'affirm', 'text': '我是。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，1363。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，1363。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，4348。', 'usr_type': 1}, {'intent': 'inform', 'text': '13636644348。', 'usr_type': 0}, {'intent': 'inform', 'text': '姓名是李先生。', 'usr_type': 0}, {'intent': 'inform', 'text': '姓名是李先生。', 'usr_type': 0}, {'intent': 'is_ok', 'text': '然后。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，我是说嗯。', 'usr_type': 1}, {'intent': 'input_servicer', 'text': '模型函数，我是说嗯。', 'usr_type': 1}, {'intent': 'is_receiver', 'text': '我是收件人。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，好，就这样。', 'usr_type': 1}, {'intent': 'is_ok', 'text': '好，就这样。', 'usr_type': 0}, {'intent': 'is_ok', 'text': '好，就这样。', 'usr_type': 0}, {'intent': 'byebye', 'text': '拜拜。', 'usr_type': 0}]
user_messages=[{'intent': 'input_servicer', 'text': '模型函数，喂喂。', 'usr_type': 1, 'sender_id': '1712898374.101216163', 'express_id_piece': True, 'express_id': False}, {'intent': 'angry', 'text': '喂喂。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，喂。', 'usr_type': 1}, {'intent': 'angry', 'text': '喂喂。', 'usr_type': 0}, {'intent': 'check_express_status', 'text': '你好，帮我查一个件。', 'usr_type': 0}, {'intent': 'check_express_status', 'text': '你好，帮我查一个件。', 'usr_type': 0}, {'intent': 'inform', 'text': '订单号为28603344。', 'usr_type': 0}, {'intent': 'inform', 'text': '8855163。', 'usr_type': 0}, {'intent': 'inform', 'text': '我的手机号是13636677378。', 'usr_type': 0}, {'intent': 'inform', 'text': '然后我姓李。', 'usr_type': 0}, {'intent': 'wait_for_a_moment', 'text': '等一下，我李先生。', 'usr_type': 0}, {'intent': 'is_receiver', 'text': '我是收件人。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，好了，何俊，我打过了，还是一样。', 'usr_type': 1}, {'intent': 'is_ok', 'text': '好了好久，我打给我还是一样。', 'usr_type': 0}]
user_messages=[{'intent': 'check_express_status', 'text': '嗯，我有一个快件，现在。', 'usr_type': 0, 'sender_id': '1712898530.101216165', 'express_id_piece': True, 'express_id': False}, {'intent': 'check_express_status', 'text': '嗯，我有一个快件，现在。', 'usr_type': 0}, {'intent': 'urge_to_process', 'text': '现在不知道。', 'usr_type': 0}, {'intent': 'pretend_signed', 'text': '这显示签收了，但是还没有收到。', 'usr_type': 0}, {'intent': 'ask_express_id', 'text': '运单号是。', 'usr_type': 0}, {'intent': 'ask_express_id', 'text': '运单号是yd。', 'usr_type': 0}, {'intent': 'inform', 'text': '2869705433。', 'usr_type': 0}, {'intent': 'is_ok', 'text': '9。', 'usr_type': 0}, {'intent': 'inform', 'text': '806。', 'usr_type': 0}, {'intent': 'inform', 'text': '手机号码是13636674348。', 'usr_type': 0}, {'intent': 'inform', 'text': '对，李先生。', 'usr_type': 0}, {'intent': 'ask_express_id', 'text': '运单号是。', 'usr_type': 0}, {'intent': 'inform', 'text': 'vt.', 'usr_type': 0}, {'intent': 'inform', 'text': '3685702344690。', 'usr_type': 0}, {'intent': 'ask_express_id', 'text': '订单号为。', 'usr_type': 0}, {'intent': 'input_servicer', 'text': '模型函数，Y.', 'usr_type': 1}, {'intent': 'inform', 'text': 'yt.', 'usr_type': 0}, {'intent': 'inform', 'text': '7896。', 'usr_type': 0}, {'intent': 'inform', 'text': '445210。', 'usr_type': 0}]

# %%
from pprint import pprint
pprint(user_messages)
# Out:
# [{'express_id': False,
#   'express_id_piece': True,
#   'intent': 'check_express_status',
#   'sender_id': '1712898530.101216165',
#   'text': '嗯，我有一个快件，现在。',
#   'usr_type': 0},
#  {'intent': 'check_express_status', 'text': '嗯，我有一个快件，现在。', 'usr_type': 0},
#  {'intent': 'urge_to_process', 'text': '现在不知道。', 'usr_type': 0},
#  {'intent': 'pretend_signed', 'text': '这显示签收了，但是还没有收到。', 'usr_type': 0},
#  {'intent': 'ask_express_id', 'text': '运单号是。', 'usr_type': 0},
#  {'intent': 'ask_express_id', 'text': '运单号是yd。', 'usr_type': 0},
#  {'intent': 'inform', 'text': '2869705433。', 'usr_type': 0},
#  {'intent': 'is_ok', 'text': '9。', 'usr_type': 0},
#  {'intent': 'inform', 'text': '806。', 'usr_type': 0},
#  {'intent': 'inform', 'text': '手机号码是13636674348。', 'usr_type': 0},
#  {'intent': 'inform', 'text': '对，李先生。', 'usr_type': 0},
#  {'intent': 'ask_express_id', 'text': '运单号是。', 'usr_type': 0},
#  {'intent': 'inform', 'text': 'vt.', 'usr_type': 0},
# ...

# %%
e = []
for i in e:
    print(i)
print(f'{e!r}')
# Out:
# []

# %%
urge_query_express = ['快件查询', '催件']
complaint = ['电话下单投诉','短信投诉','服务态度','延误','破损','遗失','错发','费用问题','超区无网点','其他','短少','海外集运','COD问题','虚假签收','无效投诉']


complaint.index('短信投诉')
# Out:
# 1

# %%
import pandas as pd
from pprint import pprint
df = pd.read_excel(r'D:\客服AI质检项目\后端数据\20240414数据\服务大小类-意图对应表v1.xlsx', header=0)

# %%
intent_service_dt = {
'add_money':[],
'address_is_wrong':[],
'affirm_to_contact':[],
'angry':[],
'ask_code':[],
'ask_damages':[],
'ask_express_id':[],
'ask_home_delivery':[],
'ask_send_on_time':[],
'cancel_to_send':[],
'change_address':[],
'change_address_or_not':[],
'check_arrive_datetime':[],
'check_client_name_phone_address':[],
'check_express_status':[],
'check_sign_info':[],
'check_weight':[],
'complaint':[],
'complaint_courier':[],
'complaint_courier_station':[],
'complaint_customer_service':[],
'complaint_did_not_sent_to_doorstep':[],
'complaint_logistics':[],
'complaint_net_station':[],
'complaint_service':[],
'consult_exception_reason':[],
'consult_expressman_phone':[],
'consult_invoice':[],
'consult_post_info':[],
'consult_send_item':[],
'consult_send_station_info':[],
'consult_station_info':[],
'did_not_contact_customer':[],
'grumble_logistics_net_courier':[],
'has_no_express_id':[],
'has_not_received':[],
'has_not_received_yet':[],
'has_sent_or_not':[],
'home_delivery':[],
'hurry':[],
'if_can_change_address':[],
'if_has_lost':[],
'is_ok_urge':[],
'is_receiver':[],
'is_sender':[],
'join_in':[],
'logistics_not_updated':[],
'no_logistics_info':[],
'no_use':[],
'not_accept_apology':[],
'not_arrive_threaten_complaint':[],
'not_process_threaten_complaint':[],
'package_damage':[],
'package_lack':[],
'package_lost':[],
'pretend_sent':[],
'pretend_signed':[],
'reject_reason':[],
'request_sent_to_delivery_cabinet':[],
'return':[],
'return_or_not':[],
'send_wrong_address':[],
'service_code':[],
'specify_method_himself':[],
'specify_method_not_courier_station':[],
'specify_method_not_him_want_address':[],
'sup_urge':[],
'threaten_complaint':[],
'tip_off':[],
'too_slow':[],
'unable_to_contact':[],
'unable_to_contact_courier':[],
'unable_to_contact_net_station':[],
'urge':[],
'urge_to_get_express':[],
'urge_to_send':[],
'urge_to_send_goods':[],
'write_wrong_address':[],
}

# %%
service_category_dt = {}
for i in df.index:
    # pprint(df.iloc[i])
    service_category_dt[df.iloc[i]['大类名称']] = service_category_dt.get(df.iloc[i]['大类名称'], set())
    service_category_dt[df.iloc[i]['大类名称']].add(df.iloc[i]['小类名称'])
    for k in intent_service_dt:
        # print('------',df.iloc[i]['小类匹配意图(唯一)'])
        if type(df.iloc[i]['小类匹配意图(唯一)']) == str:
            one_m = df.iloc[i]['小类匹配意图(唯一)'].replace('\n', '').replace(' ', '').replace('，', ',').split(',')
            print(one_m)
        if type(df.iloc[i]['小类匹配意图（非唯一）']) == str:
            m_m = df.iloc[i]['小类匹配意图（非唯一）'].replace('\n', '').replace(' ', '').replace('，', ',').split(',')
        if type(df.iloc[i]['小类匹配意图(唯一)']) == str and k in one_m and [df.iloc[i]['大类名称'],df.iloc[i]['小类名称']] not in intent_service_dt[k]: intent_service_dt[k].append([df.iloc[i]['大类名称'],df.iloc[i]['小类名称']])
        if type(df.iloc[i]['小类匹配意图（非唯一）']) == str and k in m_m and [df.iloc[i]['大类名称'],df.iloc[i]['小类名称']] not in intent_service_dt[k]: intent_service_dt[k].append([df.iloc[i]['大类名称'],df.iloc[i]['小类名称']])
pprint(service_category_dt)
pprint(intent_service_dt)
# Out:
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ['if_can_change_address']
# ...
